# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Abd Elrahman\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv(r"C:\Users\Abd Elrahman\Downloads\new11.csv")
df
# Out:
#              DATE      TIME       OPEN       HIGH        LOW      CLOSE  \
# 0      2019.04.17  09:00:00   9897.836   9897.836   9886.998   9889.714
# 1      2019.04.17  10:00:00   9889.691   9889.691   9861.678   9861.678
# 2      2019.04.17  11:00:00   9861.662   9869.139   9838.618   9866.856
# 3      2019.04.17  12:00:00   9866.856   9882.758   9855.400   9866.770
# 4      2019.04.17  13:00:00   9866.758   9868.966   9845.468   9861.392
# ...           ...       ...        ...        ...        ...        ...
# 43747  2024.04.13  07:00:00  13480.267  13520.555  13467.046  13508.110
# 43748  2024.04.13  08:00:00  13508.088  13521.118  13498.614  13500.263
# 43749  2024.04.13  09:00:00  13500.249  13537.928  13484.368  13525.617
# 43750  2024.04.13  10:00:00  13525.578  13592.225  13524.326  13570.256
# 43751  2024.04.13  11:00:00  13570.238  13575.535  13558.160  13559.326
#
#        TICKVOL  VOL  SPREAD
# 0       310687    0       0
# 1       422940    0       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43752 entries, 0 to 43751
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     43752 non-null  object
#  1   TIME     43752 non-null  object
#  2   OPEN     43752 non-null  float64
#  3   HIGH     43752 non-null  float64
#  4   LOW      43752 non-null  float64
#  5   CLOSE    43752 non-null  float64
#  6   TICKVOL  43752 non-null  int64
#  7   VOL      43752 non-null  int64
#  8   SPREAD   43752 non-null  int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 3.0+ MB

# %%
df.isnull().sum()
# Out:
# DATE       0
# TIME       0
# OPEN       0
# HIGH       0
# LOW        0
# CLOSE      0
# TICKVOL    0
# VOL        0
# SPREAD     0
# dtype: int64

# %%
df.describe()
# Out:
#                OPEN          HIGH           LOW         CLOSE       TICKVOL  \
# count  43752.000000  43752.000000  43752.000000  43752.000000  4.375200e+04
# mean   11325.015697  11342.553748  11307.627047  11325.095194  6.039900e+03
# std     1506.488297   1508.764140   1504.093331   1506.508743  4.347305e+04
# min     8340.541000   8356.761000   8328.480000   8340.548000  6.000000e+02
# 25%    10142.551250  10157.771000  10125.967250  10142.562500  3.500000e+03
# 50%    10964.415000  10981.067000  10945.902500  10964.509500  3.511000e+03
# 75%    12577.309000  12597.191500  12556.323750  12577.322250  3.521000e+03
# max    14626.255000  14645.258000  14595.989000  14626.265000  1.357110e+06
#
#            VOL        SPREAD
# count  43752.0  43752.000000
# mean       0.0   1122.318294
# std        0.0    165.033851
# min        0.0      0.000000
# 25%        0.0   1010.000000
# 50%        0.0   1090.000000
# 75%        0.0   1250.000000
# max        0.0   1450.000000

# %%
df=df.drop(['VOL','SPREAD'],axis=1)
df
# Out:
#              DATE      TIME       OPEN       HIGH        LOW      CLOSE  \
# 0      2019.04.17  09:00:00   9897.836   9897.836   9886.998   9889.714
# 1      2019.04.17  10:00:00   9889.691   9889.691   9861.678   9861.678
# 2      2019.04.17  11:00:00   9861.662   9869.139   9838.618   9866.856
# 3      2019.04.17  12:00:00   9866.856   9882.758   9855.400   9866.770
# 4      2019.04.17  13:00:00   9866.758   9868.966   9845.468   9861.392
# ...           ...       ...        ...        ...        ...        ...
# 43747  2024.04.13  07:00:00  13480.267  13520.555  13467.046  13508.110
# 43748  2024.04.13  08:00:00  13508.088  13521.118  13498.614  13500.263
# 43749  2024.04.13  09:00:00  13500.249  13537.928  13484.368  13525.617
# 43750  2024.04.13  10:00:00  13525.578  13592.225  13524.326  13570.256
# 43751  2024.04.13  11:00:00  13570.238  13575.535  13558.160  13559.326
#
#        TICKVOL
# 0       310687
# 1       422940
# 2       752470
# 3       703980
# 4       643370
# ...

# %%
plt.figure(figsize=(20, 16))
plt.boxplot(df['TICKVOL'])
plt.title('Trading')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.show()

# %%
Q1 = df['TICKVOL'].quantile(0.25)
Q3 = df['TICKVOL'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the upper and lower bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
df[df['TICKVOL']>upper_bound]
# Out:
#              DATE      TIME       OPEN       HIGH        LOW      CLOSE  \
# 0      2019.04.17  09:00:00   9897.836   9897.836   9886.998   9889.714
# 1      2019.04.17  10:00:00   9889.691   9889.691   9861.678   9861.678
# 2      2019.04.17  11:00:00   9861.662   9869.139   9838.618   9866.856
# 3      2019.04.17  12:00:00   9866.856   9882.758   9855.400   9866.770
# 4      2019.04.17  13:00:00   9866.758   9868.966   9845.468   9861.392
# ...           ...       ...        ...        ...        ...        ...
# 24652  2022.02.07  16:00:00  12633.656  12786.865  12624.840  12775.777
# 25700  2022.03.23  08:00:00  13268.299  13282.707  13250.016  13276.385
# 26378  2022.04.20  14:00:00  13413.187  13420.928  13384.720  13407.747
# 41338  2024.01.03  22:00:00  14183.787  14206.520  14164.923  14202.784
# 42202  2024.02.08  22:00:00  13982.203  14002.517  13972.290  13986.889
#
#        TICKVOL
# 0       310687
# 1       422940
# 2       752470
# 3       703980
# 4       643370
# ...

# %%
df[df['TICKVOL']<lower_bound]
# Out:
#              DATE      TIME       OPEN       HIGH        LOW      CLOSE  \
# 432    2019.05.05  09:00:00   9234.843   9251.446   9227.115   9233.122
# 642    2019.05.14  03:00:00   9027.911   9039.777   9015.961   9019.911
# 649    2019.05.14  10:00:00   9033.950   9033.950   9015.734   9022.929
# 692    2019.05.16  05:00:00   8964.594   8966.777   8948.784   8958.101
# 741    2019.05.18  06:00:00   9116.793   9117.782   9089.232   9089.232
# ...           ...       ...        ...        ...        ...        ...
# 42039  2024.02.02  03:00:00  13758.710  13780.811  13716.594  13776.493
# 42421  2024.02.18  01:00:00  14141.354  14145.002  14121.306  14121.306
# 43010  2024.03.13  14:00:00  13972.940  14032.714  13972.744  14022.454
# 43094  2024.03.17  02:00:00  14072.294  14101.285  14066.204  14091.258
# 43751  2024.04.13  11:00:00  13570.238  13575.535  13558.160  13559.326
#
#        TICKVOL
# 432       3466
# 642       3466
# 649       3466
# 692       3465
# 741       3468
# ...

# %%
df = df[df['TICKVOL'] <= upper_bound]

# %%
df[df['TICKVOL']>upper_bound]
# Out:
# Empty DataFrame
# Columns: [DATE, TIME, OPEN, HIGH, LOW, CLOSE, TICKVOL]
# Index: []

# %%
df = df[df['TICKVOL'] >= lower_bound]

# %%
df[df['TICKVOL']<lower_bound]
# Out:
# Empty DataFrame
# Columns: [DATE, TIME, OPEN, HIGH, LOW, CLOSE, TICKVOL]
# Index: []

# %%
df
# Out:
#              DATE      TIME       OPEN       HIGH        LOW      CLOSE  \
# 162    2019.04.24  03:00:00   9767.638   9767.638   9744.596   9751.724
# 163    2019.04.24  04:00:00   9751.714   9761.096   9741.547   9741.547
# 164    2019.04.24  05:00:00   9741.525   9742.245   9717.178   9717.178
# 165    2019.04.24  06:00:00   9717.167   9728.658   9705.981   9724.574
# 166    2019.04.24  07:00:00   9724.563   9724.563   9691.655   9691.655
# ...           ...       ...        ...        ...        ...        ...
# 43746  2024.04.13  06:00:00  13475.545  13497.522  13459.836  13480.291
# 43747  2024.04.13  07:00:00  13480.267  13520.555  13467.046  13508.110
# 43748  2024.04.13  08:00:00  13508.088  13521.118  13498.614  13500.263
# 43749  2024.04.13  09:00:00  13500.249  13537.928  13484.368  13525.617
# 43750  2024.04.13  10:00:00  13525.578  13592.225  13524.326  13570.256
#
#        TICKVOL
# 162       3498
# 163       3506
# 164       3485
# 165       3504
# 166       3484
# ...

# %%
plt.figure(figsize=(20, 16))
plt.boxplot(df['TICKVOL'])
plt.title('Trading')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.show()

# %%
df.describe()
# Out:
#                OPEN          HIGH           LOW         CLOSE       TICKVOL
# count  43299.000000  43299.000000  43299.000000  43299.000000  43299.000000
# mean   11337.807525  11355.359446  11320.390691  11337.871015   3510.382803
# std     1503.007890   1505.272158   1500.615435   1503.013737     14.851553
# min     8340.541000   8356.761000   8328.480000   8340.548000   3469.000000
# 25%    10159.562000  10174.116500  10143.298500  10159.634500   3500.000000
# 50%    10974.500000  10990.181000  10956.529000  10974.502000   3511.000000
# 75%    12589.944000  12610.037500  12568.097500  12589.964000   3521.000000
# max    14626.255000  14645.258000  14595.989000  14626.265000   3552.000000

# %%
sns.heatmap(df.corr())
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
#Predicting High column
X=df.drop(["CLOSE","DATE","TIME"],axis=1)
y=df["CLOSE"]

# %%
# Trainset>> X_train,y_train # Test Set >>X_test,y_test 

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mae = mean_absolute_error(y_test, y_pred)

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
print('mae : ',mae)
print('mse : ',mse)
# Out:
# mae :  7.972761805792426
# mse :  93.90518420332414

# %%
print(X)
print(y)
# Out:
#             OPEN       HIGH        LOW  TICKVOL
# 162     9767.638   9767.638   9744.596     3498
# 163     9751.714   9761.096   9741.547     3506
# 164     9741.525   9742.245   9717.178     3485
# 165     9717.167   9728.658   9705.981     3504
# 166     9724.563   9724.563   9691.655     3484
# ...          ...        ...        ...      ...
# 43746  13475.545  13497.522  13459.836     3519
# 43747  13480.267  13520.555  13467.046     3537
# 43748  13508.088  13521.118  13498.614     3526
# 43749  13500.249  13537.928  13484.368     3521
# 43750  13525.578  13592.225  13524.326     3518
#
# [43299 rows x 4 columns]
# 162       9751.724
# 163       9741.547
# 164       9717.178
# 165       9724.574
# 166       9691.655
#            ...
# 43746    13480.291
# 43747    13508.110
# 43748    13500.263
# 43749    13525.617
# 43750    13570.256
# Name: CLOSE, Length: 43299, dtype: float64

# %%
data_point = [[13528.1340, 13528.1340, 13481.0880, 3536]]
#The real value of close that we will predict = 13481.0880
# Convert data points to numeric format and reshape them
new_data = np.array(data_point)

# Make predictions
predictions = lr.predict(new_data)

# Print predictions
print(predictions)
# Out:
# [13494.62771221]
# C:\Users\Abd Elrahman\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestRegressor

# Create a Random Forest Regression model
rf_model = RandomForestRegressor(n_estimators=150, random_state=80)  # You can adjust the number of estimators (trees)

# Fit the model to the training data
rf_model.fit(X_train, y_train)

# Make predictions
rf_predictions = rf_model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, rf_predictions)
mse = mean_squared_error(y_test, rf_predictions)

print('mae : ',mae)
print('mse : ',mse)
# Out:
# mae :  7.833606304849891
# mse :  95.03122830125257

# %%
predictions = rf_model.predict(new_data)
print("Prediction of CLOSE ",predictions)
# Out:
# Prediction of CLOSE  [13495.90397333]
# C:\Users\Abd Elrahman\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create an SVR model
svr_model = SVR(kernel='rbf')  # You can specify other kernels like 'linear', 'poly', etc.

# Fit the model to the scaled training data
svr_model.fit(X_train_scaled, y_train)

# Make predictions on the scaled testing data
svr_predictions = svr_model.predict(X_test_scaled)

# %%
mae = mean_absolute_error(y_test, svr_predictions)
mse = mean_squared_error(y_test, svr_predictions)

print('mae : ',mae)
print('mse : ',mse)
# Out:
# mae :  89.38963414787789
# mse :  37513.83415432125

# %%
predictions = svr_model.predict(new_data)
print(predictions)
# Out:
# [11408.510192]

# %%
from sklearn.tree import DecisionTreeRegressor

# Create a Decision Tree Regression model
dt_model = DecisionTreeRegressor(random_state=42)  # You can specify hyperparameters like max_depth, min_samples_split, etc.

# Fit the model to the training data
dt_model.fit(X_train, y_train)

# Make predictions
dt_predictions = dt_model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, dt_predictions)
mse = mean_squared_error(y_test, dt_predictions)

print('mae : ',mae)
print('mse : ',mse)
# Out:
# mae :  9.859894341801382
# mse :  170.7039925202076

# %%
predictions = dt_model.predict(new_data)
print(predictions)
# Out:
# [13509.631]
# C:\Users\Abd Elrahman\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
